# %%
import yt
import astropy.units as u
# %matplotlib inline 
import matplotlib.pyplot as plt
import h5py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import h5py
from glob import glob

# %%
unit_base = {
    "length": (1.0, "pc"),
    "velocity": (100, "cm/s"),
    "mass": (1.0, "Msun"),
}
data = yt.load("../data/snapshot_296.hdf5", unit_base=unit_base)
# Out:
# yt : [INFO     ] 2024-04-15 20:59:38,397 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-04-15 20:59:38,419 Parameters: current_time              = 0.0002463474080710203
# yt : [INFO     ] 2024-04-15 20:59:38,419 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-04-15 20:59:38,420 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-04-15 20:59:38,420 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-04-15 20:59:38,420 Parameters: cosmological_simulation   = 0

# %%
grad_fields = data.add_gradient_fields(("gas", "temperature"))

# %%
grad_fields
# Out:
# [('gas', 'temperature_gradient_x'),
#  ('gas', 'temperature_gradient_y'),
#  ('gas', 'temperature_gradient_z'),
#  ('gas', 'temperature_gradient_magnitude')]

# %%
#data.derived_field_list

# %%
def v_mag(field, data):
    x = data[('gas','velocity_x')]
    y = data[('gas','velocity_y')]
    z = data[('gas','velocity_z')]
    vmag = np.sqrt((x)**2+(y)**2+(z)**2)
    
    return vmag


ds.add_field(
    ('gas', 'vmag'),
    function=v_mag,
    units="",
    take_log=False,
    display_name="Velocity Gradient",
    sampling_type="particle",
)


ds.force_periodicity()

# Take a slice through the center of the domain
slc = yt.SlicePlot(ds,'z', [('gas', 'vmag')], width=(1, "pc"))
slc.set_zlim(("gas", "vmag"), 0, 4e6)
# Out:
# yt : [WARNING  ] 2024-04-10 12:16:32,196 Field ('gas', 'vmag') already exists. To override use `force_override=True`.
# yt : [INFO     ] 2024-04-10 12:16:32,530 xlim = 3.580000 4.580000
# yt : [INFO     ] 2024-04-10 12:16:32,530 ylim = 3.580000 4.580000
# yt : [INFO     ] 2024-04-10 12:16:32,531 xlim = 3.580000 4.580000
# yt : [INFO     ] 2024-04-10 12:16:32,531 ylim = 3.580000 4.580000
# yt : [INFO     ] 2024-04-10 12:16:32,532 Making a fixed resolution buffer of (('gas', 'vmag')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
