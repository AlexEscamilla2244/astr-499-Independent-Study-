# %%
import yt
import astropy.units as u
# %matplotlib inline 
import matplotlib.pyplot as plt
import h5py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import h5py
from glob import glob

# %%
unit_base = {
    "length": (1.0, "pc"),
    "velocity": (100, "cm/s"),
    "mass": (1.0, "Msun"),
}

fns = [
    "../data/snapshot_150.hdf5",
    "../data/snapshot_200.hdf5",
    "../data/snapshot_250.hdf5",
    "../data/snapshot_296.hdf5",
]
datadir = '../data/'
paths = glob('../data/' + '/*.hdf5')

# %%
for f in fns:
    ds = yt.load(f, unit_base = unit_base)
    def v_mag(field, data):
        x = data[('gas', 'velocity_x')]
        y = data[('gas', 'velocity_y')]
        z = data[('gas', 'velocity_z')]
        vmag = np.sqrt((x)**2+(y)**2+(z)**2)

        return vmag

    ds.add_field(
    ("gas", "vmag"),
    units="cm/s",
    function=v_mag,
    sampling_type="cell",
    )
    
#ds.derived_field_list
# Out:
# yt : [INFO     ] 2024-03-19 16:10:25,614 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:10:25,636 Parameters: current_time              = 0.00012483821354781577
# yt : [INFO     ] 2024-03-19 16:10:25,637 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:10:25,637 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:10:25,637 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:10:25,637 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:10:25,659 Allocating for 1.214e+07 particles
# Loading particle index: 100%|█████████████████| 47/47 [00:00<00:00, 2936.40it/s]
# yt : [INFO     ] 2024-03-19 16:10:25,999 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:10:26,016 Parameters: current_time              = 0.00016645095139860156
# yt : [INFO     ] 2024-03-19 16:10:26,016 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:10:26,016 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:10:26,016 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:10:26,017 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:10:26,041 Allocating for 1.177e+07 particles
# Loading particle index: 100%|█████████████████| 45/45 [00:00<00:00, 3763.81it/s]
# yt : [INFO     ] 2024-03-19 16:10:26,273 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:10:26,291 Parameters: current_time              = 0.00020806368924938733
# yt : [INFO     ] 2024-03-19 16:10:26,291 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:10:26,292 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:10:26,292 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:10:26,292 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:10:26,312 Allocating for 1.118e+07 particles
# Loading particle index: 100%|█████████████████| 43/43 [00:00<00:00, 3477.86it/s]
# yt : [INFO     ] 2024-03-19 16:10:26,599 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:10:26,612 Parameters: current_time              = 0.0002463474080710203
# yt : [INFO     ] 2024-03-19 16:10:26,612 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:10:26,613 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:10:26,613 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:10:26,613 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:10:26,633 Allocating for 1.084e+07 particles
# Loading particle index: 100%|█████████████████| 42/42 [00:00<00:00, 3162.67it/s]

# %%
def LocateStar(data):
    ds = yt.load(data,unit_base = unit_base) 
    ad = ds.all_data()
    MassStar = ad["PartType5", "Masses"].in_units('Msun')
    ParticleID = ad['PartType5', 'ParticleIDs']
    Coordinates = ad['PartType5', 'Coordinates'].in_units('pc')
    sort = np.argmax(MassStar)
    Center = Coordinates[sort]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid

import yt

unit_base = {
    "length": (1.0, "pc"),
    "velocity": (100, "cm/s"),
    "mass": (1.0, "Msun"),
}

fns = [
    "../data/snapshot_150.hdf5",
    "../data/snapshot_200.hdf5",
    "../data/snapshot_250.hdf5",
    "../data/snapshot_296.hdf5",
]

fig = plt.figure()
    
grid = AxesGrid(fig,
(0.075, 0.075, 0.85, 0.85),
nrows_ncols=(2, 2),
axes_pad=0.05,
label_mode="L",
share_all=True,
cbar_location="right",
cbar_mode="single",
cbar_size="3%",
cbar_pad="0%",
)

for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn, unit_base = unit_base)  # load data
    ad = ds.all_data()
    MassStar = ad["PartType5", "Masses"].in_units('Msun')
    ParticleID = ad['PartType5', 'ParticleIDs']
    Coordinates = ad['PartType5', 'Coordinates'].in_units('pc')
    sort = np.argmax(MassStar)
    Center = Coordinates[sort]
    dir = 2

    left_corner = ds.domain_left_edge.copy()
    right_corner = ds.domain_right_edge.copy()
    
    depth = ds.quan(.1, "pc")
    left_corner[dir] = Center[dir] - 0.5 * depth
    right_corner[dir] = Center[dir] + 0.5 * depth


    region = ds.box(left_corner, right_corner)
    p = yt.ProjectionPlot(ds, "z", ("PartType0", "HII"), width=(1, "pc"), center = Center, weight_field = ('gas', 'density'))
    

    # Ensure the colorbar limits match for all plots
    p.set_zlim(("PartType0", "HII"), 1e-9, 1)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots[("PartType0", "HII")]
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]

    # Finally, this actually redraws the plot.
    p.render()
plt.savefig('hii 499 plot')
# Out:
# yt : [INFO     ] 2024-03-19 16:10:26,884 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:10:26,898 Parameters: current_time              = 0.00012483821354781577
# yt : [INFO     ] 2024-03-19 16:10:26,898 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:10:26,899 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:10:26,899 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:10:26,899 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:10:26,917 Allocating for 1.214e+07 particles
# Loading particle index: 100%|█████████████████| 47/47 [00:00<00:00, 4966.80it/s]
# yt : [INFO     ] 2024-03-19 16:10:27,212 xlim = 3.521577 4.521577
# yt : [INFO     ] 2024-03-19 16:10:27,213 ylim = 3.129129 4.129129
# yt : [INFO     ] 2024-03-19 16:10:27,213 xlim = 3.521577 4.521577
# yt : [INFO     ] 2024-03-19 16:10:27,214 ylim = 3.129129 4.129129
# yt : [INFO     ] 2024-03-19 16:10:27,215 Making a fixed resolution buffer of (('PartType0', 'HII')) 800 by 800
# yt : [INFO     ] 2024-03-19 16:10:35,355 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2024-03-19 16:10:43,240 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:10:43,254 Parameters: current_time              = 0.00016645095139860156
# yt : [INFO     ] 2024-03-19 16:10:43,254 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:10:43,254 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:10:43,255 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:10:43,255 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:10:43,276 Allocating for 1.177e+07 particles
# Loading particle index: 100%|█████████████████| 45/45 [00:00<00:00, 3633.74it/s]
# yt : [INFO     ] 2024-03-19 16:10:43,566 xlim = 3.667164 4.667164
# yt : [INFO     ] 2024-03-19 16:10:43,566 ylim = 3.383960 4.383960
# yt : [INFO     ] 2024-03-19 16:10:43,567 xlim = 3.667164 4.667164
# yt : [INFO     ] 2024-03-19 16:10:43,567 ylim = 3.383960 4.383960
# yt : [INFO     ] 2024-03-19 16:10:43,568 Making a fixed resolution buffer of (('PartType0', 'HII')) 800 by 800
# yt : [INFO     ] 2024-03-19 16:10:52,729 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2024-03-19 16:11:01,692 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:11:01,708 Parameters: current_time              = 0.00020806368924938733
# yt : [INFO     ] 2024-03-19 16:11:01,708 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:11:01,709 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:11:01,709 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:11:01,709 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:11:01,730 Allocating for 1.118e+07 particles
# Loading particle index: 100%|█████████████████| 43/43 [00:00<00:00, 2069.19it/s]
# yt : [INFO     ] 2024-03-19 16:11:01,984 xlim = 3.598267 4.598267
# yt : [INFO     ] 2024-03-19 16:11:01,984 ylim = 3.496552 4.496552
# yt : [INFO     ] 2024-03-19 16:11:01,985 xlim = 3.598267 4.598267
# yt : [INFO     ] 2024-03-19 16:11:01,986 ylim = 3.496552 4.496552
# yt : [INFO     ] 2024-03-19 16:11:01,986 Making a fixed resolution buffer of (('PartType0', 'HII')) 800 by 800
# yt : [INFO     ] 2024-03-19 16:11:10,776 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2024-03-19 16:11:19,449 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-03-19 16:11:19,463 Parameters: current_time              = 0.0002463474080710203
# yt : [INFO     ] 2024-03-19 16:11:19,463 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-03-19 16:11:19,463 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-03-19 16:11:19,464 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-03-19 16:11:19,464 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-03-19 16:11:19,485 Allocating for 1.084e+07 particles
# Loading particle index: 100%|█████████████████| 42/42 [00:00<00:00, 2944.45it/s]
# yt : [INFO     ] 2024-03-19 16:11:19,708 xlim = 3.598877 4.598877
# yt : [INFO     ] 2024-03-19 16:11:19,708 ylim = 3.475362 4.475362
# yt : [INFO     ] 2024-03-19 16:11:19,709 xlim = 3.598877 4.598877
# yt : [INFO     ] 2024-03-19 16:11:19,709 ylim = 3.475362 4.475362
# yt : [INFO     ] 2024-03-19 16:11:19,710 Making a fixed resolution buffer of (('PartType0', 'HII')) 800 by 800

# %%
fig = plt.figure()
    
grid = AxesGrid(fig,
(0.075, 0.075, 0.85, 0.85),
nrows_ncols=(2, 2),
axes_pad=0.05,
label_mode="L",
share_all=True,
cbar_location="right",
cbar_mode="single",
cbar_size="3%",
cbar_pad="0%",
)

for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn, unit_base = unit_base)  # load data
    ad = ds.all_data()
    MassStar = ad["PartType5", "Masses"].in_units('Msun')
    ParticleID = ad['PartType5', 'ParticleIDs']
    Coordinates = ad['PartType5', 'Coordinates'].in_units('pc')
    sort = np.argmax(MassStar)
    Center = Coordinates[sort]
    dir = 2

    left_corner = ds.domain_left_edge.copy()
    right_corner = ds.domain_right_edge.copy()
    
    depth = ds.quan(.1, "pc")
    left_corner[dir] = Center[dir] - 0.5 * depth
    right_corner[dir] = Center[dir] + 0.5 * depth


    region = ds.box(left_corner, right_corner)
    p = yt.ProjectionPlot(ds, "z", ("gas", "density"), width=(1, "pc"), center = Center, weight_field = ('gas', 'density'))
    

    # Ensure the colorbar limits match for all plots
    p.set_zlim(("gas", "density"), 1e-15, 1e-20)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots[("gas", "density")]
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]

    # Finally, this actually redraws the plot.
    p.render()

plt.savefig('499 density plots')

# %%
fig = plt.figure()
    
grid = AxesGrid(fig,
(0.075, 0.075, 0.85, 0.85),
nrows_ncols=(2, 2),
axes_pad=0.05,
label_mode="L",
share_all=True,
cbar_location="right",
cbar_mode="single",
cbar_size="3%",
cbar_pad="0%",
)

for i, fn in enumerate(fns):
    # Load the data and create a single plot
    ds = yt.load(fn, unit_base = unit_base)  # load data
    dir = 2

    left_corner = ds.domain_left_edge.copy()
    right_corner = ds.domain_right_edge.copy()
    
    depth = ds.quan(.1, "pc")
    left_corner[dir] = Center[dir] - 0.5 * depth
    right_corner[dir] = Center[dir] + 0.5 * depth


    region = ds.box(left_corner, right_corner)
    p = yt.ProjectionPlot(ds, "z", ("gas", "temperature"), width=(1, "pc"), center = Center, weight_field = ('gas', 'density'))
    

    # Ensure the colorbar limits match for all plots
    p.set_zlim(("gas", "temperature"), 1, 2e4)

    # This forces the ProjectionPlot to redraw itself on the AxesGrid axes.
    plot = p.plots[("gas", "temperature")]
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]

    # Finally, this actually redraws the plot.
    p.render()

plt.savefig('temperature plots 499')

# %%
#ds = yt.load(fns[3], unit_base = unit_base)  # load data
p = yt.ProjectionPlot(ds, "z", ("gas", "temperature"), width=(1, "pc"), center = Center, weight_field = ('gas', 'density'))
    

    # Ensure the colorbar limits match for all plots
p.set_zlim(("gas", "temperature"), 1, 2e4)

p.show()
