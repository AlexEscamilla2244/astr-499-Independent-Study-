# %%
import yt
import astropy.units as u
# %matplotlib inline 
import matplotlib.pyplot as plt
import h5py
#yt.toggle_interactivity()

dataFile = 'data/snapshot_150.hdf5'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import yt
#       2 import astropy.units as u
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'yt'

# %%
unit_base = {
    "length": (1.0, "pc"),
    "velocity": (100.0, "cm/s"),
    "mass": (1.0, "Msun")
}
ds = yt.load('data/snapshot_150.hdf5', unit_base = unit_base)
# Out:
# yt : [INFO     ] 2024-02-19 12:15:00,436 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2024-02-19 12:15:00,519 Parameters: current_time              = 0.00012483821354781577
# yt : [INFO     ] 2024-02-19 12:15:00,521 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-02-19 12:15:00,524 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-02-19 12:15:00,527 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-02-19 12:15:00,528 Parameters: cosmological_simulation   = 0

# %%
#ds.derived_field_list

# %%
ad = ds.all_data()
density = ad['PartType0', 'Density'].in_units('g/cm**3.')
vmag = ad['PartType0', 'particle_velocity_magnitude'].in_units('km/s')

partIDs = ad['PartType0', 'ParticleIDs']
print(f'{partIDs.min()} \t {partIDs.max()}')

print(f'Density = {density.max()}')
print(f'vmin = {vmag.min()} \t vmin = {vmag.max()}')
# Out:
# 1.0 dimensionless 	 1913298393.0 dimensionless
# Density = 1.6995519756531778e-13 g/cm**3
# vmin = 0.002685007729474139 km/s 	 vmin = 214.25672647988162 km/s

# %%
search_by_type = (ad["PartType5", "Velocities"]).in_units('km/s')
vmag_stars = (ad["PartType5", 'particle_velocity_magnitude']).in_units('km/s')
mstar = (ad["PartType5", 'Masses']).in_units('Msun')
print(f'Star Velocities = {search_by_type}')
print(f'Star Vmag min = {vmag_stars.min()} \t Star Vmag max = {vmag_stars.max()}')
print(f'Star Mass min = {mstar.min()} \t Star Mass max = {mstar.max()}')
# Out:
# Star Velocities = [[  1.05768518  -2.53281177   1.35109338]
#  [ -1.75162146   2.99300464 -10.72804785]
#  [  2.07684277  -1.87739331  -2.537448  ]
#  ...
#  [  4.07188403  -2.15853564  -0.18361487]
#  [  0.11814554   1.2095647    2.32737842]
#  [  2.73763794   2.95772046   1.73987463]] km/s
# Star Vmag min = 0.3420367602403941 km/s 	 Star Vmag max = 28.237971824049733 km/s
# Star Mass min = 0.0020000000949949026 Msun 	 Star Mass max = 8.331499099731445 Msun

# %%
sp = ds.sphere([0,0,0], (4, "pc"))

# %%
CoM = (sp.quantities.center_of_mass()* u.cm).to(u.pc)
print(CoM)
# Out:
# [4.07977682 4.0808035  4.07863818] pc

# %%
ds.all_data()
# Out:
# YTRegion (snapshot_150): , center=[1.25895645e+19 1.25895645e+19 1.25895645e+19] cm, left_edge=[0. 0. 0.] cm, right_edge=[2.51791291e+19 2.51791291e+19 2.51791291e+19] cm

# %%
pwidth = (4.0,'pc')
projUnit = ["g/cm**2", "g/cm**3", "km/s"]
weightField = [None, ("PartType0", "density"), ("PartType0", "density")]
#'Msun/pc**2'
proFields = [("PartType0", "density"), ("PartType0", "density"), ("PartType0", 'particle_velocity_magnitude')]

for i, field in enumerate(proFields):
    plot = yt.ProjectionPlot(ds, "y", field, width = pwidth, weight_field = weightField[i])
    p.set_axes_unit('pc')
    p.set_unit(field, projUnit[i])
    #p.annotate_particles(pwidth)
    p.show()
# Out:
# yt : [INFO     ] 2024-02-16 13:25:40,388 xlim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:25:40,389 ylim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:25:40,391 xlim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:25:40,395 ylim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:25:40,401 Making a fixed resolution buffer of (('PartType0', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2024-02-16 13:26:00,911 xlim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:00,915 ylim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:00,917 xlim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:00,918 ylim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:00,922 Making a fixed resolution buffer of (('PartType0', 'density')) 800 by 800
# yt : [INFO     ] 2024-02-16 13:26:21,062 Making a fixed resolution buffer of (('PartType0', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2024-02-16 13:26:41,277 xlim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:41,278 ylim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:41,280 xlim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:41,282 ylim = 2.080000 6.080000
# yt : [INFO     ] 2024-02-16 13:26:41,287 Making a fixed resolution buffer of (('PartType0', 'particle_velocity_magnitude')) 800 by 800
# yt : [INFO     ] 2024-02-16 13:27:03,954 Making a fixed resolution buffer of (('PartType0', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
grad_fields = ds.add_gradient_fields(("gas", "temperature"))

# %%
grad_fields
# Out:
# [('gas', 'temperature_gradient_x'),
#  ('gas', 'temperature_gradient_y'),
#  ('gas', 'temperature_gradient_z'),
#  ('gas', 'temperature_gradient_magnitude')]

# %%
ad["PartType0", "Density"]
# Out:
# unyt_array([16065.83203125, 25908.5       , 30100.171875  , ...,
#             46262.8046875 , 44841.18359375, 40575.89453125], 'code_mass/code_length**3')

# %%
ds.mass_unit
# Out:
# unyt_quantity(1.e+10, 'Msun')

# %%
ds.length_unit
# Out:
# unyt_quantity(1., 'kpc')

# %%
source = ds.sphere("c", (10, "kpc"))
profile = source.profile(
    [("gas", "density")],  # the bin field
    [
        ("gas", "temperature"),  # profile field
        ("gas", "radial_velocity"),
    ],  # profile field
    weight_field=("gas", "mass"),
)

# %%
print(profile.x)  # bin field
print(profile.weight)  # weight field
print(profile["gas", "temperature"])  # profile field
print(profile["gas", "radial_velocity"])  # profile field
print(profile.used)
# Out:
# [2.71752940e-22 3.87750129e-22 5.53260481e-22 7.89418591e-22
#  1.12638031e-21 1.60717345e-21 2.29319216e-21 3.27203656e-21
#  4.66869871e-21 6.66152324e-21 9.50498086e-21 1.35621626e-20
#  1.93511441e-20 2.76111405e-20 3.93968995e-20 5.62133859e-20
#  8.02079551e-20 1.14444557e-19 1.63294984e-19 2.32997115e-19
#     56.75445087    63.73266282    73.93924003    85.62797361
#     97.58429965   110.19296716   129.53761939   151.26083715
#    182.3536752    214.1377546    247.43981302   321.70431725
#    442.12880441   483.5193887    873.24067378   259.16873075] dimensionless
# [-4.61986480e+09 -3.25204756e+09 -2.36472550e+09 -1.57233906e+09
#  -1.06340485e+09 -5.29274561e+08 -1.76083901e+08  2.17002344e+06
#   1.89876814e+08  1.92933695e+08  1.14935151e+08  1.88421273e+08
#   2.24821565e+08  2.42922174e+08  2.49520670e+08  2.53372142e+08
#   2.45533140e+08  2.39183998e+08  2.34428415e+08  2.17363430e+08
#   1.86664254e+08  1.54267892e+08  1.25972169e+08  9.75615834e+07
#   6.89802090e+07  4.49101557e+07  2.04439804e+07  1.16381226e+06
#  -1.25847482e+07 -2.33079655e+07 -3.44987267e+07 -4.46585451e+07
#  -5.69381948e+07 -6.81568769e+07 -8.03459334e+07 -8.97258208e+07
#  -9.61404041e+07 -1.00233651e+08 -1.05469350e+08 -1.08065622e+08
#  -1.09441884e+08 -1.09871473e+08 -1.10158974e+08 -1.10288107e+08
#  -1.13574064e+08 -1.14695336e+08 -1.15966361e+08 -1.16734282e+08
#  -1.16510427e+08 -1.15380965e+08 -1.20981636e+08 -1.14047636e+08
#  -1.19683124e+08 -1.17766187e+08 -1.20499964e+08 -1.28795009e+08
#  -1.34492552e+08 -1.23603459e+08 -1.52353570e+08 -2.02983620e+08
#  -2.55483932e+08 -3.16463116e+08 -4.12899492e+08 -3.04445276e+08] cm/s
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]

# %%
my_sphere = ds.sphere("c", (80.0, "kpc"))

# Create a PhasePlot object.
# Setting weight to None will calculate a sum.
# Setting weight to a field will calculate an average
# weighted by that field.
plot = yt.PhasePlot(
    my_sphere,
    ("gas", "density"),
    ("gas", "temperature"),
    ("gas", "mass"),
    weight_field=None,
)

# Set the units of mass to be in solar masses (not the default in cgs)
plot.set_unit(("gas", "mass"), "Msun")
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p = yt.ParticlePlot(
    ds,
    ("all", "particle_position_x"),
    ("all", "particle_position_y"),
    ("all", "particle_mass"),
    width=(0.5, 0.5),
)

# pick some appropriate units
p.set_axes_unit("kpc")
p.set_unit(("all", "particle_mass"), "Msun")
# Out:
# yt : [INFO     ] 2024-02-15 20:02:26,890 xlim = 3.830000 4.330000
# yt : [INFO     ] 2024-02-15 20:02:26,891 ylim = 3.830000 4.330000
# yt : [INFO     ] 2024-02-15 20:02:26,892 xlim = 3.830000 4.330000
# yt : [INFO     ] 2024-02-15 20:02:26,894 ylim = 3.830000 4.330000
# yt : [INFO     ] 2024-02-15 20:02:26,901 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh using method 'ngp'
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ts = yt.DatasetSeries(['data/snapshot_150.hdf5'])
