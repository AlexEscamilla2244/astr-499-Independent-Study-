# %%
import yt
import astropy.units as u
# %matplotlib inline 
import matplotlib.pyplot as plt
import h5py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import h5py
from glob import glob

# %%
unit_base = {
    "length": (1.0, "pc"),
    "velocity": (100, "cm/s"),
    "mass": (1.0, "Msun"),
}
data = yt.load("../data/snapshot_296.hdf5", unit_base=unit_base)
# Out:
# yt : [INFO     ] 2024-04-15 21:03:35,029 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-04-15 21:03:35,051 Parameters: current_time              = 0.0002463474080710203
# yt : [INFO     ] 2024-04-15 21:03:35,051 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-04-15 21:03:35,052 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-04-15 21:03:35,052 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-04-15 21:03:35,052 Parameters: cosmological_simulation   = 0

# %%
def LocateStar(data):
    ad = data.all_data()
    MassStar = ad["PartType5", "Masses"].in_units('Msun')
    ParticleID = ad['PartType5', 'ParticleIDs']
    print(ParticleID.size)
    Coordinates = ad['PartType5', 'Coordinates'].in_units('pc')
    sort = np.argmax(MassStar)
    Center = Coordinates[sort]
    return Center

# %%
def Particle_Limits(data):
    ad = data.all_data()
    ParticleID =  ad['PartType5', 'ParticleIDs']
    range = (ParticleID < 1e6 )
    return range

# %%
dir = 2
Center = LocateStar(data)
left_corner = data.domain_left_edge.copy()
right_corner = data.domain_right_edge.copy()
depth = data.quan(.5, "pc")
left_corner[dir] = Center[dir] - 0.5 * depth
right_corner[dir] = Center[dir] + 0.5 * depth


region = data.box(left_corner, right_corner)
p = yt.ProjectionPlot(data, "z", ("PartType0", "HII"), width= depth, center = Center, weight_field = ('gas', 'density'))
p.set_zlim(("PartType0", "HII"), 1e-9, 1)

p
# Out:
# yt : [INFO     ] 2024-04-15 21:06:24,456 xlim = 3.848877 4.348877
# yt : [INFO     ] 2024-04-15 21:06:24,456 ylim = 3.725362 4.225362
# yt : [INFO     ] 2024-04-15 21:06:24,457 xlim = 3.848877 4.348877
# yt : [INFO     ] 2024-04-15 21:06:24,458 ylim = 3.725362 4.225362
# yt : [INFO     ] 2024-04-15 21:06:24,458 Making a fixed resolution buffer of (('PartType0', 'HII')) 800 by 800
# 1871
# yt : [INFO     ] 2024-04-15 21:06:33,223 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slc = yt.ProjectionPlot(data, "z", ('PartType0', 'MolecularMassFraction'), width= depth, center = Center, weight_field = ('PartType0', 'temperature'))
slc
# Out:
# yt : [INFO     ] 2024-04-15 21:12:49,428 xlim = 3.848877 4.348877
# yt : [INFO     ] 2024-04-15 21:12:49,429 ylim = 3.725362 4.225362
# yt : [INFO     ] 2024-04-15 21:12:49,431 xlim = 3.848877 4.348877
# yt : [INFO     ] 2024-04-15 21:12:49,432 ylim = 3.725362 4.225362
# yt : [INFO     ] 2024-04-15 21:12:49,433 Making a fixed resolution buffer of (('PartType0', 'MolecularMassFraction')) 800 by 800
# yt : [INFO     ] 2024-04-15 21:12:57,883 Making a fixed resolution buffer of (('PartType0', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.ProjectionPlot(data, "z", ('gas', 'H_density'), width= depth, center = Center, weight_field = ('gas', 'temperature'))
slice
# Out:
# yt : [INFO     ] 2024-04-15 21:11:48,131 xlim = 3.848877 4.348877
# yt : [INFO     ] 2024-04-15 21:11:48,132 ylim = 3.725362 4.225362
# yt : [INFO     ] 2024-04-15 21:11:48,134 xlim = 3.848877 4.348877
# yt : [INFO     ] 2024-04-15 21:11:48,135 ylim = 3.725362 4.225362
# yt : [INFO     ] 2024-04-15 21:11:48,136 Making a fixed resolution buffer of (('gas', 'H_density')) 800 by 800
# yt : [INFO     ] 2024-04-15 21:11:57,197 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
