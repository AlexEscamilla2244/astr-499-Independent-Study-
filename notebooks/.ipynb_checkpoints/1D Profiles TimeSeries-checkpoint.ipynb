# %%
import yt
import astropy.units as u
# %matplotlib inline 
import matplotlib.pyplot as plt
import h5py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import h5py
from glob import glob

# %%
unit_base = {
    "length": (1.0, "pc"),
    "velocity": (100, "cm/s"),
    "mass": (1.0, "Msun"),
}

fns = [
    "../data/snapshot_150.hdf5",
    "../data/snapshot_200.hdf5",
    "../data/snapshot_250.hdf5",
    "../data/snapshot_296.hdf5",
]
datadir = '../data/'
paths = glob('../data/' + '/*.hdf5')

# %%
profiles = []
labels = []
for i, fn in enumerate(fns):
    ds = yt.load(fn, unit_base = unit_base)  
    ad = ds.all_data()
    MassStar = ad["PartType5", "Masses"].in_units('Msun')
    Coordinates = ad['PartType5', 'Coordinates'].in_units('pc')
    sort = np.argmax(MassStar)
    Center = Coordinates[sort]
    sphere = ds.sphere(Center, (0.05, 'pc'))
    fields = ("PartType0", "HII")
    profiles.append(
        yt.create_profile(
            sphere,
            [("PartType0", "temperature")],
            fields=fields,
            weight_field=None,
            accumulation=True,
        )
    )

plot = yt.ProfilePlot.from_profiles(profiles, labels=None)
plot
# Out:
# yt : [INFO     ] 2024-04-22 18:11:46,896 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-04-22 18:11:46,921 Parameters: current_time              = 0.00012483821354781577
# yt : [INFO     ] 2024-04-22 18:11:46,921 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-04-22 18:11:46,921 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-04-22 18:11:46,922 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-04-22 18:11:46,922 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-04-22 18:11:46,947 Allocating for 1.214e+07 particles
# Loading particle index: 100%|█████████████████| 47/47 [00:00<00:00, 4358.73it/s]
# yt : [INFO     ] 2024-04-22 18:11:47,507 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-04-22 18:11:47,520 Parameters: current_time              = 0.00016645095139860156
# yt : [INFO     ] 2024-04-22 18:11:47,520 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-04-22 18:11:47,521 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-04-22 18:11:47,521 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-04-22 18:11:47,521 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-04-22 18:11:47,541 Allocating for 1.177e+07 particles
# Loading particle index: 100%|█████████████████| 45/45 [00:00<00:00, 3737.57it/s]
# yt : [INFO     ] 2024-04-22 18:11:48,622 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-04-22 18:11:48,635 Parameters: current_time              = 0.00020806368924938733
# yt : [INFO     ] 2024-04-22 18:11:48,636 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-04-22 18:11:48,636 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-04-22 18:11:48,636 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-04-22 18:11:48,636 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-04-22 18:11:48,656 Allocating for 1.118e+07 particles
# Loading particle index: 100%|█████████████████| 43/43 [00:00<00:00, 3290.97it/s]
# yt : [INFO     ] 2024-04-22 18:11:49,608 ComovingIntegrationOn != 1 or (not found and OmegaLambda is 0.0), so we are turning off Cosmology.
# yt : [INFO     ] 2024-04-22 18:11:49,621 Parameters: current_time              = 0.0002463474080710203
# yt : [INFO     ] 2024-04-22 18:11:49,622 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2024-04-22 18:11:49,622 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-04-22 18:11:49,622 Parameters: domain_right_edge         = [8.16 8.16 8.16]
# yt : [INFO     ] 2024-04-22 18:11:49,622 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2024-04-22 18:11:49,680 Allocating for 1.084e+07 particles
# Loading particle index: 100%|█████████████████| 42/42 [00:00<00:00, 1995.27it/s]
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
